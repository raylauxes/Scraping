# %%
import importlib
importlib.reload(googleCrawler)
from googleCrawler import *
import pandas as pd

# %%
word_list = ["ai", "自然言語処理", "サービス"]

result = top_10_sites(word_list)
# Out:
# 自然言語処理-NLP-サービスの価格比較と企業一覧を紹介します。 AIsmileyはAI・人工知能を搭載した製品プロダクト・ソリューション・ベンダーの導入活用事例の紹介や比較一覧、資料請求が無料でできるAIポータルメディアです。
# ----------------------------------------------------------------------------------------------------
# 自然言語処理（文章解析）とは. 形態素解析. 日本語は、ひらがな、カタカナ、漢字が入り混じる構造になっており、 文字列 ...
# ----------------------------------------------------------------------------------------------------
# 自然言語処理・機械学習（人工知能）の機能を自社サービスに 取り入れたい企業様に最適です。 □運用の流れ. : ヒアリング及び見積; : 見積、貴社向けカスタマイズ; : APIご提供 ...
# ----------------------------------------------------------------------------------------------------
# ... 導入・開発の目的別で解説. #AINOW編集部#データサイエンス#ディープラーニング#プログラミング#事例#会話#機械学習#自然言語処理 2020.03.05 ... する「Asales」がリリース. #AI開発企業#サービスリリース#自然言語処理 2018.11.30 ...
# ----------------------------------------------------------------------------------------------------
# 2019/08/07 — しかし、その大量のデータを処理可能な自然言語処理技術は、これまでリーガルやコールセンターなどの限られた ... そのBERTを自社のサービスに活用している会社が、2016年に設立された東京大学発ベンチャー、ストック ...
# ...

# %%
for i in result:
    display(i)
    print("-"*100)
# Out:
# '自然言語処理-NLP-サービスの価格比較と企業一覧を紹介します。 AIsmileyはAI・人工知能を搭載した製品プロダクト・ソリューション・ベンダーの導入活用事例の紹介や比較一覧、資料請求が無料でできるAIポータルメディアです。'
# ----------------------------------------------------------------------------------------------------
# '自然言語処理（文章解析）とは. 形態素解析. 日本語は、ひらがな、カタカナ、漢字が入り混じる構造になっており、 文字列 ...'
# ----------------------------------------------------------------------------------------------------
# '自然言語処理・機械学習（人工知能）の機能を自社サービスに 取り入れたい企業様に最適です。 □運用の流れ. : ヒアリング及び見積; : 見積、貴社向けカスタマイズ; : APIご提供 ...'
# ----------------------------------------------------------------------------------------------------
# '... 導入・開発の目的別で解説. #AINOW編集部#データサイエンス#ディープラーニング#プログラミング#事例#会話#機械学習#自然言語処理 2020.03.05 ... する「Asales」がリリース. #AI開発企業#サービスリリース#自然言語処理 2018.11.30 ...'
# ----------------------------------------------------------------------------------------------------
# '2019/08/07 — しかし、その大量のデータを処理可能な自然言語処理技術は、これまでリーガルやコールセンターなどの限られた ... そのBERTを自社のサービスに活用している会社が、2016年に設立された東京大学発ベンチャー、ストック ...'
# ...

# %%
result_df = pd.DataFrame(result)
result_df
# Out:
#                                                    0
# 0  自然言語処理-NLP-サービスの価格比較と企業一覧を紹介します。 AIsmileyはAI・人...
# 1  自然言語処理（文章解析）とは. 形態素解析. 日本語は、ひらがな、カタカナ、漢字が入り混じる...
# 2  自然言語処理・機械学習（人工知能）の機能を自社サービスに 取り入れたい企業様に最適です。 □...
# 3  ... 導入・開発の目的別で解説. #AINOW編集部#データサイエンス#ディープラーニング...
# 4  2019/08/07 — しかし、その大量のデータを処理可能な自然言語処理技術は、これまでリ...
# 5  ディープラーニングを含めた機械学習、自然言語処理、数理最適化などは、人工知能（AI）を実現す...
# 6  2020/08/12 — 自然言語処理とは、人間の「自然」発話を処理する、あらゆる機械やプロ...
# 7  2020/06/04 — 今回は、機械学習や自然言語処理に便利なツールを紹介していきます。ぜ...
# 8  2019/08/07 — 身近にある自然言語処理を使ったサービス. 自然言語処理は、例えばS...
# 9  データアーティスト株式会社 | Data Artist | AI（人工知能）の自然言語処理(...
